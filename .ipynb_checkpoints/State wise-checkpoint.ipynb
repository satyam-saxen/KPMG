# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel('newCustomerList.xlsx')

# %%
df
# Out:
#      Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                            first_name
# 1                                               Chickie
# 2                                                 Morly
# 3                                               Ardelis
# 4                                                Lucine
# ...                                                 ...
# 996                                           Ferdinand
# 997                                                Burk
# 998                                            Melloney
# 999                                              Dickie
# 1000                                              Sylas
#
#      Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0     last_name     gender  past_3_years_bike_related_purchases
# ...

# %%
df.columns=df.iloc[0]

# %%
df
# Out:
# 0     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0     first_name  last_name  gender  past_3_years_bike_related_purchases
# 1        Chickie    Brister    Male                                   86
# 2          Morly     Genery    Male                                   69
# 3        Ardelis  Forrester  Female                                   10
# 4         Lucine      Stutt  Female                                   64
# ...          ...        ...     ...                                  ...
# 996    Ferdinand  Romanetti    Male                                   60
# 997         Burk    Wortley    Male                                   22
# 998     Melloney      Temby  Female                                   17
# 999       Dickie    Cubbini    Male                                   30
# 1000       Sylas    Duffill    Male                                   56
#
# 0                     DOB                     job_title  \
# ...

# %%
df = df.iloc[pd.RangeIndex(len(df)).drop(0)]

# %%
df
# Out:
# 0    first_name  last_name  gender past_3_years_bike_related_purchases  \
# 1       Chickie    Brister    Male                                  86
# 2         Morly     Genery    Male                                  69
# 3       Ardelis  Forrester  Female                                  10
# 4        Lucine      Stutt  Female                                  64
# 5       Melinda     Hadlee  Female                                  34
# ...         ...        ...     ...                                 ...
# 996   Ferdinand  Romanetti    Male                                  60
# 997        Burk    Wortley    Male                                  22
# 998    Melloney      Temby  Female                                  17
# 999      Dickie    Cubbini    Male                                  30
# 1000      Sylas    Duffill    Male                                  56
#
# 0                     DOB                     job_title job_industry_category  \
# ...

# %%
df.state.unique()
# Out:
# array(['QLD', 'NSW', 'VIC'], dtype=object)

# %%
x = df['state'].nunique()

# %%
N=0
Q=0
V=0
for index,rows in df.iterrows():
    if rows['state']== 'NSW':
        N+=1
    elif rows['state']=='QLD':
        Q+=1
    else:
        V+=1

# %%
data = {
    'State_Person':['NSW_car','NSW_NC','QLD_car','QLD_NC','VIC_car','VIC_NC'],
    'Car Owned':[234,272,134,132,125,103]
}

# %%
dfs = pd.DataFrame(data,columns = ['State_Person','Car Owned'])

# %%
sns.barplot(x=dfs['State_Person'],y=dfs['Car Owned'])
